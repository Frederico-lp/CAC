# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

import tensorflow_datasets as tfds

# %%
ds, info = tfds.load('amazon_us_reviews/Software_v1_00', split='train', shuffle_files=True, with_info=True)


print(ds)
print(info)
# Out:
# <PrefetchDataset element_spec={'data': {'customer_id': TensorSpec(shape=(), dtype=tf.string, name=None), 'helpful_votes': TensorSpec(shape=(), dtype=tf.int32, name=None), 'marketplace': TensorSpec(shape=(), dtype=tf.string, name=None), 'product_category': TensorSpec(shape=(), dtype=tf.string, name=None), 'product_id': TensorSpec(shape=(), dtype=tf.string, name=None), 'product_parent': TensorSpec(shape=(), dtype=tf.string, name=None), 'product_title': TensorSpec(shape=(), dtype=tf.string, name=None), 'review_body': TensorSpec(shape=(), dtype=tf.string, name=None), 'review_date': TensorSpec(shape=(), dtype=tf.string, name=None), 'review_headline': TensorSpec(shape=(), dtype=tf.string, name=None), 'review_id': TensorSpec(shape=(), dtype=tf.string, name=None), 'star_rating': TensorSpec(shape=(), dtype=tf.int32, name=None), 'total_votes': TensorSpec(shape=(), dtype=tf.int32, name=None), 'verified_purchase': TensorSpec(shape=(), dtype=tf.int64, name=None), 'vine': TensorSpec(shape=(), dtyp
# ...

# %%
tfds.as_dataframe(ds.take(2),info)
# Out:
#   data/customer_id  data/helpful_votes data/marketplace data/product_category  \
# 0      b'13682385'                   0            b'US'           b'Software'
# 1      b'14511828'                   0            b'US'           b'Software'
#
#   data/product_id data/product_parent           data/product_title  \
# 0   b'B00HM3QP5W'        b'236221549'             b'Final Draft 9'
# 1   b'B00EP7AQ4O'        b'422519054'  b'Family Tree Maker Deluxe'
#
#                                     data/review_body data/review_date  \
# 0  b"I haven't worked for a long time with Final ...    b'2015-06-23'
# 1  b'This was a gift for my husband.  He does a l...    b'2014-01-01'
#
#      data/review_headline     data/review_id  data/star_rating  \
# 0  b'Superior Phone Help'  b'R29TNLNSTBABBK'                 3
# 1           b'Great gift'  b'R37A2WMRCZLRCI'                 5
#
#    data/total_votes  data/verified_purchase  data/vine
# 0                 0                       1          1
# ...

# %%
#info.features['data']

for review in ds: 
  print(review['data']['customer_id'])
  # image = example["image"]
  # label = example["label"]
  # print(image.shape, label)

#training, test = ds_numpy[:70,:], ds_numpy[70:,:]
# Out:
# tf.Tensor(b'16092114', shape=(), dtype=string)
# tf.Tensor(b'41249792', shape=(), dtype=string)
# tf.Tensor(b'49439957', shape=(), dtype=string)
# tf.Tensor(b'15588846', shape=(), dtype=string)
# tf.Tensor(b'22541830', shape=(), dtype=string)
# tf.Tensor(b'15346573', shape=(), dtype=string)
# tf.Tensor(b'26381152', shape=(), dtype=string)
# tf.Tensor(b'51028896', shape=(), dtype=string)
# tf.Tensor(b'49268875', shape=(), dtype=string)
# tf.Tensor(b'22241260', shape=(), dtype=string)
# tf.Tensor(b'46145669', shape=(), dtype=string)
# tf.Tensor(b'51181698', shape=(), dtype=string)
# tf.Tensor(b'53078687', shape=(), dtype=string)
# tf.Tensor(b'38227392', shape=(), dtype=string)
# tf.Tensor(b'17824530', shape=(), dtype=string)
# tf.Tensor(b'48490550', shape=(), dtype=string)
# tf.Tensor(b'13682385', shape=(), dtype=string)
# tf.Tensor(b'14511828', shape=(), dtype=string)
# tf.Tensor(b'6518553', shape=(), dtype=string)
# tf.Tensor(b'44623565', shape=(), dtype=string)
# ...
